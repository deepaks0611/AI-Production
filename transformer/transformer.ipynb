# %% [markdown]
# # `Transformer`

# %% [markdown]
# ## Attention Is All You Need

# %% [markdown]
# ## `Embedding`
#
# echo "# AI-Production" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/deepaks0611/AI-Production.git
# git push -u origin main
